# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.spatial.distance import cdist
from tqdm.notebook import tqdm
import IPython

# %% [markdown]
# Reading in Data

# %%
"""Katies reading in files"""
players = pd.read_csv("players.csv")
week = pd.read_csv("tracking_week_1.csv")
plays = pd.read_csv("plays.csv")
tackles = pd.read_csv("tackles.csv")


# join player positioning information onto a week's worth of tracking data 
week = week.merge(players.loc[:, ['nflId', 'position']], how='left')
week.shape

# %%
""" Matts reading in files """
def load_dataset(dataset_name):
    """
    Download a specific dataset from data directory.

    Parameters:
    - dataset_name: Name of the dataset to load
    """
    return pd.read_csv(f"C:\\Users\\mattd\\Documents\\GitHub\\big-data-bowl-2024\\data\\{dataset_name}.csv")

# Read In csvs
plays = load_dataset("plays")
players = load_dataset("players")
week = load_dataset("tracking_week_1")
tackles = load_dataset("tackles")
week = week.merge(players.loc[:, ['nflId', 'position']], how='left')
week.shape
# Out:
# (1407439, 18)

# %% [markdown]
# Defining Functions for feature engineering at each level
#
# (Just put in ones I thought of, if it has #TO DO: over it then it isnt complete/not started)

# %%
"""Game level functions"""

def get_frames_of_catch(games):
    """
    Returns only the frame of the play where the ball is caught.

    Parameters:
    - games: Dataset of games

    Returns:
    - frame: The tracking data of only the data where the ball is caught
    """
    return games.loc[games['event'] == 'pass_outcome_caught'].copy()

# %%
"""Frame level functions"""
def distance_to_ball(play_data, frame):
    """
    Calculates the distance to the ball for each player per frame in a play.

    Parameters:
    - dataset_name: Name of the dataset to load
    """
    ball_carrier_id = play_data["ballCarrierId"].iloc[0]
    ball_carrier = frame[frame["nflId"] == ball_carrier_id]
    carr_x = ball_carrier["x"].values[0]
    carr_y = ball_carrier["y"].values[0]
    frame['distance_to_ball_carrier'] = cdist(frame[['x', 'y']], [[carr_x, carr_y]], metric='euclidean')
    return frame

def who_tackles(play_data, frame):
    """
    Adds who tackles the ball carrier to the tracking data set.

    Parameters:
    - dataset_name: Name of the dataset to load
    """
    ball_carrier_id = play_data["ballCarrierId"].iloc[0]
    ball_carrier = frame[frame["nflId"] == ball_carrier_id]
    carr_x = ball_carrier["x"].values[0]
    carr_y = ball_carrier["y"].values[0]
    frame['distance_to_ball_carrier'] = cdist(frame[['x', 'y']], [[carr_x, carr_y]], metric='euclidean')
    return frame

def create_dnn_input_df(frames, side_of_ball):
    """
    Creates the input dataframe for the DNN model.

    Parameters:
    - frames: Name of the dataset to load
    """
    sorted = frames.sort_values(by='distance_to_ball_carrier').reset_index(drop=True)
    
    input_df = pd.DataFrame()
    # Iterate over each row in the sorted DataFrame
    for idx, row in sorted.iterrows():
        # Extract player's x and y values
        x = row['x']
        y = row['y']
        s = row['s']
        a = row['a']
        dis = row['dis']
        o = row['o']
        dir = row['dir']
        distance_to_ball_carrier = row['distance_to_ball_carrier']


        # Add x_i columns to the new DataFrame
        input_df.loc[0,f'{side_of_ball}_x_{idx}'] = x
        input_df.loc[0,f'{side_of_ball}_y_{idx}'] = y
        input_df.loc[0,f'{side_of_ball}_s_{idx}'] = s
        input_df.loc[0,f'{side_of_ball}_a_{idx}'] = a
        input_df.loc[0,f'{side_of_ball}_dis_{idx}'] = dis
        input_df.loc[0,f'{side_of_ball}_o_{idx}'] = o
        input_df.loc[0,f'{side_of_ball}_dir_{idx}'] = dir
        input_df.loc[0,f'{side_of_ball}_distance_to_ball_carrier_{idx}'] = distance_to_ball_carrier

    # Concatenate the original DataFrame with the new x_i DataFrame
    return input_df

# %% [markdown]
# Iterating through each Play

# %%
# Process each game, play, and frame
pass_only = get_frames_of_catch(week)
df = pd.DataFrame()
for gid in tqdm(pass_only['gameId'].unique(), leave=True):
    game = pass_only.loc[pass_only['gameId'] == gid].copy()
    game_plays = plays[plays['gameId'] == gid]
    game_tackles = tackles[tackles['gameId'] == gid]

    for pid in tqdm(game['playId'].unique(), leave=False):
        play = game.loc[game['playId'] == pid].copy()
        play_data = game_plays[game_plays['playId'] == pid]
        play_tackles = game_tackles[game_tackles['playId'] == pid]  

        #Adding distance to ball carrier as a feature in tracking data
        play = distance_to_ball(play_data, play)

        offense = play[play["club"] == play_data["possessionTeam"].iloc[0]]
        defense = play[play["club"] == play_data["defensiveTeam"].iloc[0]]
        #print(defense.head())
        #print("Length of ",len(defense))

        offense_input = create_dnn_input_df(offense, "o")
        defense_input = create_dnn_input_df(defense, "d")
        print(defense_input.head())

        
        

        #Adding who tackled the ball carrier
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/52 [00:00<?, ?it/s]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0   d_o_0  d_dir_0  \
# 0  78.15  37.85   5.88   1.23     0.59  140.96    178.5
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      2.828003  76.71  33.36  ...   305.29
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                       21.8936   70.62    7.66     2.6    4.14      0.27
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0  331.57    278.33                      29.415605
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0  d_o_0  d_dir_0  \
# 0  68.93  34.26   4.44   3.47     0.45  18.51   358.93
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      4.278329  70.95   34.7  ...   310.45
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     30.639067   45.18   11.65    3.89    2.12      0.39
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0   82.35    239.91                      35.097602
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0   d_o_0  d_dir_0  \
# 0  51.35  30.31   5.21   2.97      0.5  187.23   208.17
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      2.462214  50.93  20.42  ...   244.43
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     16.774296    45.4   12.28    6.13    4.05      0.61
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0  321.01    314.26                      16.807335
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0   d_o_0  d_dir_0  \
# 0  37.54  46.02    8.6   1.23     0.86  355.17   336.33
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      0.861452   45.1  44.99  ...   334.25
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     22.870352   31.09    9.99     1.6    0.78      0.16
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0     1.3      27.2                       37.46415
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0   d_o_0  d_dir_0  \
# 0  24.86  38.82   7.56   0.96     0.76  299.98   313.74
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      8.202103  15.78  35.99  ...   283.62
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     29.965954    34.1   17.89    0.63    1.18      0.07
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0  319.93     246.5                      30.755188
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0   d_o_0  d_dir_0  \
# 0  53.76   3.53   7.56   2.54     0.77  172.32   177.23
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      3.783385  47.16   4.74  ...   153.88
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     47.273859   36.41    46.2    2.82    1.68      0.29
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0   127.7     52.29                      48.250059
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0   d_o_0  d_dir_0  \
# 0  53.05  18.27   3.48   1.56     0.36  221.95   149.26
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      4.462118  57.03  18.64  ...   114.91
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     32.255607   67.18   43.53    6.07    2.41      0.61
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0  154.12     94.71                      33.247659
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0   d_o_0  d_dir_0  \
# 0  67.79  46.06   5.06    1.2      0.5  274.86   311.15
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      5.826706  72.73  34.23  ...    17.86
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                      24.44838   59.95   11.22    3.96    3.68      0.39
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0  343.14    316.58                      28.352707
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0   d_o_0  d_dir_0  \
# 0  66.95   6.22   7.64   1.55     0.77  141.89   176.89
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      2.384156  53.23  18.44  ...   277.76
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     44.915503   47.09   48.13    4.83    2.32      0.49
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0  110.05    281.64                      48.719718
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0  d_o_0  d_dir_0  \
# 0  52.45  15.78    4.5   2.98     0.46  246.6   213.98
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      1.010198  46.69  22.87  ...   209.07
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     27.715564   63.81   49.79    3.97    5.52      0.37
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0   84.93     58.17                      35.570336
#
# [1 rows x 88 columns]
# 1
# 1
#     d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0  d_o_0  d_dir_0  \
# 0  108.33   8.02   9.69   2.85     0.98  86.21     92.0
#
#    d_distance_to_ball_carrier_0   d_x_1  d_y_1  ...  d_dir_9  \
# 0                          1.07  102.45  21.71  ...   124.51
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     53.628149   58.17   29.27     1.2    0.42      0.12
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0  122.26    103.13                      55.462378
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0   d_o_0  d_dir_0  \
# 0  96.44  22.28   4.91   2.74      0.5  190.82   195.94
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                       9.05221  98.13  22.22  ...   278.53
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     37.400092   75.82   44.97    3.89     2.8      0.39
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0  122.61    300.41                      37.587437
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0  d_o_0  d_dir_0  \
# 0  74.76   34.4    4.7   1.45     0.46  69.89    37.39
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      5.381868  76.27  28.76  ...   335.53
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     27.964392   56.38   14.13    3.14    5.32       0.3
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0   12.52    346.16                      31.640512
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0  d_o_0  d_dir_0  \
# 0  70.05  13.67   3.06   3.36     0.32  71.26    86.91
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      1.175457  70.38  14.99  ...   217.97
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     29.160379   66.81   48.63    0.57    5.78      0.09
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0  180.37     331.7                      35.047295
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0  d_o_0  d_dir_0  \
# 0  65.72  45.28   7.43   0.49     0.73  45.63    26.74
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      2.098118  66.04  37.16  ...   335.73
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     34.955333    65.2    4.65    0.57    2.57      0.06
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0   24.51    218.59                      41.590465
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0  d_o_0  d_dir_0  \
# 0  75.48  38.72   5.41   0.93     0.54  60.69    21.82
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      2.413649   72.0  33.67  ...   229.96
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     24.520785   79.96    9.96     1.6    3.11      0.17
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0   58.81    287.99                      30.148899
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0  d_o_0  d_dir_0  \
# 0  70.52  27.98   4.93   0.77     0.49  34.73    25.72
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      2.229484  78.08  29.36  ...   145.94
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     21.558966    55.5    9.41    5.97     3.4       0.6
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0  336.76    290.28                      26.094047
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0  d_o_0  d_dir_0  \
# 0  64.06  44.66   6.39   2.12     0.65  18.35    11.33
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                       3.17657  60.46   47.6  ...   355.17
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     28.876816   62.87    13.4    1.94    3.39      0.19
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0  354.59     306.1                      34.447178
#
# [1 rows x 88 columns]
# 1
# 1
#    d_x_0  d_y_0  d_s_0  d_a_0  d_dis_0   d_o_0  d_dir_0  \
# 0  61.57  33.34   5.04   2.21      0.5  204.67    206.7
#
#    d_distance_to_ball_carrier_0  d_x_1  d_y_1  ...  d_dir_9  \
# 0                      5.106271  52.77  28.23  ...   150.55
#
#    d_distance_to_ball_carrier_9  d_x_10  d_y_10  d_s_10  d_a_10  d_dis_10  \
# 0                     20.065259   43.74   41.68    4.58    2.48      0.47
#
#    d_o_10  d_dir_10  d_distance_to_ball_carrier_10
# 0  219.75    283.45                      21.641731
#
# [1 rows x 88 columns]
# 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mattd\Documents\GitHub\big-data-bowl-2024\venv\lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'o_x_8'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mattd\Documents\GitHub\big-data-bowl-2024\venv\lib\site-packages\pandas\core\frame.py:4261, in DataFrame._set_item_mgr(self, key, value, refs)
#    4260 try:
# -> 4261     loc = self._info_axis.get_loc(key)
#    4262 except KeyError:
#    4263     # This item wasn't present, just insert at end
#
# File c:\Users\mattd\Documents\GitHub\big-data-bowl-2024\venv\lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#
# KeyError: 'o_x_8'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\mattd\Documents\GitHub\big-data-bowl-2024\src\notebooks\metrics\feature_engineering.ipynb Cell 9 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/mattd/Documents/GitHub/big-data-bowl-2024/src/notebooks/metrics/feature_engineering.ipynb#X10sZmlsZQ%3D%3D?line=17'>18</a> defense = play[play["club"] == play_data["defensiveTeam"].iloc[0]]
#      <a href='vscode-notebook-cell:/c%3A/Users/mattd/Documents/GitHub/big-data-bowl-2024/src/notebooks/metrics/feature_engineering.ipynb#X10sZmlsZQ%3D%3D?line=18'>19</a> #print(defense.head())
#      <a href='vscode-notebook-cell:/c%3A/Users/mattd/Documents/GitHub/big-data-bowl-2024/src/notebooks/metrics/feature_engineering.ipynb#X10sZmlsZQ%3D%3D?line=19'>20</a> #print("Length of ",len(defense))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/mattd/Documents/GitHub/big-data-bowl-2024/src/notebooks/metrics/feature_engineering.ipynb#X10sZmlsZQ%3D%3D?line=21'>22</a> offense_input = create_dnn_input_df(offense, "o")
#      <a href='vscode-notebook-cell:/c%3A/Users/mattd/Documents/GitHub/big-data-bowl-2024/src/notebooks/metrics/feature_engineering.ipynb#X10sZmlsZQ%3D%3D?line=22'>23</a> defense_input = create_dnn_input_df(defense, "d")
#      <a href='vscode-notebook-cell:/c%3A/Users/mattd/Documents/GitHub/big-data-bowl-2024/src/notebooks/metrics/feature_engineering.ipynb#X10sZmlsZQ%3D%3D?line=23'>24</a> print(defense_input.head())
#
# c:\Users\mattd\Documents\GitHub\big-data-bowl-2024\src\notebooks\metrics\feature_engineering.ipynb Cell 9 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/mattd/Documents/GitHub/big-data-bowl-2024/src/notebooks/metrics/feature_engineering.ipynb#X10sZmlsZQ%3D%3D?line=58'>59</a> distance_to_ball_carrier = row['distance_to_ball_carrier']
#      <a href='vscode-notebook-cell:/c%3A/Users/mattd/Documents/GitHub/big-data-bowl-2024/src/notebooks/metrics/feature_engineering.ipynb#X10sZmlsZQ%3D%3D?line=61'>62</a> # Add x_i columns to the new DataFrame
# ---> <a href='vscode-notebook-cell:/c%3A/Users/mattd/Documents/GitHub/big-data-bowl-2024/src/notebooks/metrics/feature_engineering.ipynb#X10sZmlsZQ%3D%3D?line=62'>63</a> input_df.loc[0,f'{side_of_ball}_x_{idx}'] = x
#      <a href='vscode-notebook-cell:/c%3A/Users/mattd/Documents/GitHub/big-data-bowl-2024/src/notebooks/metrics/feature_engineering.ipynb#X10sZmlsZQ%3D%3D?line=63'>64</a> input_df.loc[0,f'{side_of_ball}_y_{idx}'] = y
#      <a href='vscode-notebook-cell:/c%3A/Users/mattd/Documents/GitHub/big-data-bowl-2024/src/notebooks/metrics/feature_engineering.ipynb#X10sZmlsZQ%3D%3D?line=64'>65</a> input_df.loc[0,f'{side_of_ball}_s_{idx}'] = s
#
# File c:\Users\mattd\Documents\GitHub\big-data-bowl-2024\venv\lib\site-packages\pandas\core\indexing.py:885, in _LocationIndexer.__setitem__(self, key, value)
#     882 self._has_valid_setitem_indexer(key)
#     884 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 885 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\mattd\Documents\GitHub\big-data-bowl-2024\venv\lib\site-packages\pandas\core\indexing.py:1844, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1840     self.obj[key] = empty_value
#    1842 else:
#    1843     # FIXME: GH#42099#issuecomment-864326014
# -> 1844     self.obj[key] = infer_fill_value(value)
#    1846 new_indexer = convert_from_missing_indexer_tuple(
#    1847     indexer, self.obj.axes
#    1848 )
#    1849 self._setitem_with_indexer(new_indexer, value, name)
#
# File c:\Users\mattd\Documents\GitHub\big-data-bowl-2024\venv\lib\site-packages\pandas\core\frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File c:\Users\mattd\Documents\GitHub\big-data-bowl-2024\venv\lib\site-packages\pandas\core\frame.py:4314, in DataFrame._set_item(self, key, value)
#    4311             value = np.tile(value, (len(existing_piece.columns), 1)).T
#    4312             refs = None
# -> 4314 self._set_item_mgr(key, value, refs)
#
# File c:\Users\mattd\Documents\GitHub\big-data-bowl-2024\venv\lib\site-packages\pandas\core\frame.py:4264, in DataFrame._set_item_mgr(self, key, value, refs)
#    4261     loc = self._info_axis.get_loc(key)
#    4262 except KeyError:
#    4263     # This item wasn't present, just insert at end
# -> 4264     self._mgr.insert(len(self._info_axis), key, value, refs)
#    4265 else:
#    4266     self._iset_item_mgr(loc, value, refs=refs)
#
# File c:\Users\mattd\Documents\GitHub\big-data-bowl-2024\venv\lib\site-packages\pandas\core\internals\managers.py:1344, in BlockManager.insert(self, loc, item, value, refs)
#    1342 else:
#    1343     self._insert_update_mgr_locs(loc)
# -> 1344     self._insert_update_blklocs_and_blknos(loc)
#    1346 self.axes[0] = new_axis
#    1347 self.blocks += (block,)
#
# File c:\Users\mattd\Documents\GitHub\big-data-bowl-2024\venv\lib\site-packages\pandas\core\internals\managers.py:1380, in BlockManager._insert_update_blklocs_and_blknos(self, loc)
#    1377 # Accessing public blklocs ensures the public versions are initialized
#    1378 if loc == self.blklocs.shape[0]:
#    1379     # np.append is a lot faster, let's use it if we can.
# -> 1380     self._blklocs = np.append(self._blklocs, 0)
#    1381     self._blknos = np.append(self._blknos, len(self.blocks))
#    1382 elif loc == 0:
#    1383     # np.append is a lot faster, let's use it if we can.
#
# File c:\Users\mattd\Documents\GitHub\big-data-bowl-2024\venv\lib\site-packages\numpy\lib\function_base.py:5617, in append(arr, values, axis)
#    5615     values = ravel(values)
#    5616     axis = arr.ndim-1
# -> 5617 return concatenate((arr, values), axis=axis)
#
# KeyboardInterrupt:

# %%
play
# Out:
#              gameId  playId    nflId         displayName  frameId  \
# 1406225  2022091200    3826  38605.0      Russell Wilson        6
# 1406278  2022091200    3826  41369.0     Cameron Fleming        6
# 1406331  2022091200    3826  41464.0       Shelby Harris        6
# 1406384  2022091200    3826  42543.0       Quandre Diggs        6
# 1406437  2022091200    3826  42827.0      Justin Coleman        6
# 1406490  2022091200    3826  43384.0      Graham Glasgow        6
# 1406543  2022091200    3826  43436.0   Quinton Jefferson        6
# 1406596  2022091200    3826  44832.0       Garett Bolles        6
# 1406649  2022091200    3826  44873.0          Josh Jones        6
# 1406702  2022091200    3826  46109.0    Courtland Sutton        6
# 1406755  2022091200    3826  46711.0           Ryan Neal        6
# 1406808  2022091200    3826  47824.0       Dalton Risner        6
# 1406861  2022091200    3826  47941.0     Michael Jackson        6
# 1406914  2022091200    3826  52423.0         Jerry Jeudy        6
# 1406967  2022091200    3826  52435.0       Jordyn Brooks        6
# 1407020  2022091200    3826  52454.0         K.J. Hamler        6
# 1407073  2022091200    3826  52456.0      Darrell Taylor        6
# 1407126  2022091200    3826  52491.0   Lloyd Cushenberry        6
# 1407179  2022091200    3826  52526.0  Albert Okwuegbunam        6
# 1407232  2022091200    3826  53464.0    Javonte Williams        6
# 1407285  2022091200    3826  54505.0           Boye Mafe        6
# 1407338  2022091200    3826  54618.0        Tariq Woolen        6
# 1407391  2022091200    3826      NaN            football        6
#
#                                time  jerseyNumber      club playDirection  \
# 1406225  2022-09-12 23:05:53.500000           3.0       DEN          left
# 1406278  2022-09-12 23:05:53.500000          73.0       DEN          left
# 1406331  2022-09-12 23:05:53.500000          93.0       SEA          left
# 1406384  2022-09-12 23:05:53.500000           6.0       SEA          left
# 1406437  2022-09-12 23:05:53.500000          28.0       SEA          left
# 1406490  2022-09-12 23:05:53.500000          61.0       DEN          left
# 1406543  2022-09-12 23:05:53.500000          77.0       SEA          left
# 1406596  2022-09-12 23:05:53.500000          72.0       DEN          left
# 1406649  2022-09-12 23:05:53.500000          13.0       SEA          left
# 1406702  2022-09-12 23:05:53.500000          14.0       DEN          left
# 1406755  2022-09-12 23:05:53.500000          26.0       SEA          left
# 1406808  2022-09-12 23:05:53.500000          66.0       DEN          left
# 1406861  2022-09-12 23:05:53.500000          30.0       SEA          left
# 1406914  2022-09-12 23:05:53.500000          10.0       DEN          left
# 1406967  2022-09-12 23:05:53.500000          56.0       SEA          left
# 1407020  2022-09-12 23:05:53.500000           1.0       DEN          left
# 1407073  2022-09-12 23:05:53.500000          52.0       SEA          left
# 1407126  2022-09-12 23:05:53.500000          79.0       DEN          left
# 1407179  2022-09-12 23:05:53.500000          85.0       DEN          left
# 1407232  2022-09-12 23:05:53.500000          33.0       DEN          left
# 1407285  2022-09-12 23:05:53.500000          53.0       SEA          left
# 1407338  2022-09-12 23:05:53.500000          27.0       SEA          left
# 1407391  2022-09-12 23:05:53.500000           NaN  football          left
#
#                  x      y     s     a   dis       o     dir  \
# 1406225  73.950000  29.06  0.52  1.05  0.05  157.72   16.57
# 1406278  70.650000  32.66  0.80  0.85  0.08  249.02  217.68
# 1406331  73.420000  27.15  1.88  1.76  0.19  331.49  118.69
# 1406384  39.860000  17.78  4.10  5.07  0.40  141.94  184.77
# 1406437  60.590000  12.24  6.30  2.68  0.63  103.59  136.76
# 1406490  68.990000  31.92  1.54  0.51  0.16  291.42  265.14
# 1406543  69.030000  28.24  3.50  0.92  0.36  112.81  184.46
# 1406596  73.360000  27.72  1.63  1.44  0.17  249.93  120.74
# 1406649  49.620000  32.42  4.63  4.05  0.44  143.62  159.31
# 1406702  50.250000  16.29  3.66  4.63  0.39  335.66  281.33
# 1406755  35.040000  38.82  2.61  6.42  0.26  132.69  212.57
# 1406808  72.370000  27.58  2.31  2.37  0.24  157.60  164.51
# 1406861  50.040000  43.59  3.27  3.61  0.32  189.23  211.51
# 1406914  59.870000  36.48  2.52  3.02  0.27  133.68  343.82
# 1406967  50.630000  24.43  4.24  4.80  0.40  149.93  168.05
# 1407020  44.920000  44.15  8.06  1.86  0.81   73.42  289.75
# 1407073  68.050000  32.23  4.29  1.03  0.47  192.51  229.93
# 1407126  69.540000  28.60  2.92  0.77  0.30  187.21  181.64
# 1407179  52.840000  30.37  1.80  0.97  0.18  143.23  173.54
# 1407232  70.570000  11.96  3.91  2.22  0.39  313.03  192.49
# 1407285  71.560000  25.09  4.80  3.11  0.47  183.52  187.27
# 1407338  51.220000  16.13  3.22  4.63  0.34  335.44  296.50
# 1407391  70.529999  12.14  5.55  1.14  0.56     NaN     NaN
#
#                        event position  distance_to_ball_carrier
# 1406225  pass_outcome_caught       QB                 17.430846
# 1406278  pass_outcome_caught        T                 20.700155
# 1406331  pass_outcome_caught       DE                 15.455051
# 1406384  pass_outcome_caught       FS                 31.256623
# 1406437  pass_outcome_caught       CB                  9.983927
# 1406490  pass_outcome_caught        G                 20.022437
# 1406543  pass_outcome_caught       DE                 16.352676
# 1406596  pass_outcome_caught        T                 16.005052
# 1406649  pass_outcome_caught       FS                 29.283342
# 1406702  pass_outcome_caught       WR                 20.776220
# 1406755  pass_outcome_caught       SS                 44.540324
# 1406808  pass_outcome_caught        G                 15.723371
# 1406861  pass_outcome_caught       CB                 37.708591
# 1406914  pass_outcome_caught       WR                 26.752951
# 1406967  pass_outcome_caught      ILB                 23.518174
# 1407020  pass_outcome_caught       WR                 41.159672
# 1407073  pass_outcome_caught      OLB                 20.426045
# 1407126  pass_outcome_caught        C                 16.671848
# 1407179  pass_outcome_caught       TE                 25.559362
# 1407232  pass_outcome_caught       RB                  0.000000
# 1407285  pass_outcome_caught      OLB                 13.167270
# 1407338  pass_outcome_caught       CB                 19.794226
# 1407391  pass_outcome_caught      NaN                  0.184391
